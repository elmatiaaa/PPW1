# %% [markdown]
# # **UAS PPW**

# %% [markdown]
# # Aplikasi Projek
#
# Streamlit :

# %% [markdown]
# # **Install dan Import Library**

# %% [markdown]
# Library yang digunakan yaitu :
#
# 1. Requests --> library untuk mengirim permintaan HTTP di Python dengan cara yang sederhana dan mudah dipahami.
# 2. Beautifulsoup4 --> library Python yang memudahkan ekstraksi informasi dari dokumen HTML dan XML. Berguna untuk melakukan web scraping dan parsing data dari halaman web.
# 3. Pandas --> library untuk analisis data. Ini digunakan untuk membaca, mengolah, dan menganalisis data dalam format yang disebut DataFrame.
# 4. CSV --> library untuk membaca dan menulis data dari atau ke file CSV.

# %%
# !pip install requests
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.11.17)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)

# %%
import pandas as pd
import requests
import csv
from bs4 import BeautifulSoup

# %% [markdown]
# # **Crawling Berita**

# %% [markdown]
# Crawling berita kali ini terdapat 3 kategori:
# 1. Otomotif
# 2. Megapolitan
# 3. Tren yang terjadi
#
# Cara crawling yang saya lakukan disini yaitu dengan mengambil judul dan isi beritanya saja. Untuk mengambil judul dan isi berita disini dapat diproses melalui class yang ada pada elemen web berita online.
#
# Setiap kategori memiliki halaman berita yang berbeda-beda, dapat dimasukkan pada variabel n yang sudah saya sediakan.

# %% [markdown]
# ## Otomotif

# %%
header={
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'
}

linkberita = 'https://otomotif.kompas.com/'
listpolitik = []
n = 41

for halaman in range(1, n+1):
  req = requests.get(linkberita)
  soup = BeautifulSoup(req.text, 'html.parser')
  items = soup.findAll('div', 'article__list clearfix') #class semua berita
  for it in items:
    link = it.find('a','article__link')['href'] #class perberita

    req2 = requests.get(link)
    soup2 = BeautifulSoup(req2.text, 'html.parser')
    judul = soup2.find('h1', 'read__title').text    #class judul berita
    isi = "".join(soup2.find('div', 'read__content').text.split('\n'))

    listpolitik.append([judul,isi])

# %% [markdown]
# # Megapolitan

# %%
header={
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'
}

linkberita = 'https://megapolitan.kompas.com/'
listt = []
n = 50

for halaman in range(1, n+1):
  req = requests.get(linkberita)
  soup = BeautifulSoup(req.text, 'html.parser')
  items = soup.findAll('div', 'article__list clearfix') #class semua berita
  for it in items:
    link = it.find('a','article__link')['href'] #class perberita

    req2 = requests.get(link)
    soup2 = BeautifulSoup(req2.text, 'html.parser')
    judul = soup2.find('h1', 'read__title').text    #class judul berita
    isi = "".join(soup2.find('div', 'read__content').text.split('\n'))

    listt.append([judul,isi])

# %% [markdown]
# Menggabungkan 2 data crawling berita politik dan nasional menjadi 1 data frame dan memberikan label.

# %%
politik = pd.DataFrame(listpolitik, columns=['Judul', 'Isi'])
politik['Label'] = 'otomotif'

nasional = pd.DataFrame(listt, columns=['Judul', 'Isi'])
nasional['Label'] = 'megapolitan'

gabung = [politik, nasional]
combined_df = pd.concat(gabung, ignore_index=True)
combined_df
# Out:
#                                                  Judul  \
# 0    Sultan Korban Kabel Menjuntai Akan Lanjutkan K...
# 1    Aktivitas Firli Bahuri Usai Tak Aktif Jadi Ket...
# 2    Firli Bahuri Tak Hadiri Peringatan Hari Antiko...
# 3    Pemilik Bengkel di Bogor Diduga Dianiaya Tetan...
# 4    Bertambah 315 Kasus Covid-19 di Jakarta dalam ...
# ..                                                 ...
# 795  Antisipasi Penularan Covid-19, Warga Diimbau P...
# 796  Punya Hak Pilih, Pemilih ODGJ Bakal Didampingi...
# 797  Dishub DKI Pastikan Tak Ada Pembatasan Penumpa...
# 798  Ammar Zoni Kembali Ditangkap, Polisi Sita Ganj...
# 799  Kasus Covid-19 di Tangsel Melonjak, Dinkes: Se...
#
#                                                    Isi        Label
# 0    JAKARTA, KOMPAS.com - Sultan Rif'at Alfatih, k...  megapolitan
# 1    JAKARTA, KOMPAS.com - Ketua Komisi Pemberantas...  megapolitan
# 2    JAKARTA, KOMPAS.com - Ketua Komisi Pemberantas...  megapolitan
# 3    BOGOR, KOMPAS.com - HSN (75), lansia pemilik b...  megapolitan
# 4    JAKARTA, KOMPAS.com - Dinas Kesehatan (Dinkes)...  megapolitan
# ..                                                 ...          ...
# 795  JAKARTA, KOMPAS.com - Kepala Dinas Perhubungan...  megapolitan
# 796  JAKARTA, KOMPAS.com - Pemilih kategori orang d...  megapolitan
# 797  JAKARTA, KOMPAS.com - Dinas Perhubungan (Dishu...  megapolitan
# 798  JAKARTA, KOMPAS.com - Satuan Reserse Narkoba P...  megapolitan
# 799  TANGERANG SELATAN, KOMPAS.com - Dinas Kesehata...  megapolitan
#
# [800 rows x 3 columns]

# %%
combined_df.to_csv('otomega.csv',  index=False)

# %% [markdown]
# ## Tren

# %%
header={
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'
}

urlberita = 'https://www.kompas.com/tren?source=navbar'
beritatren = []
n = 50

for halaman in range(1, n+1):
  req1 = requests.get(urlberita)
  soup1 = BeautifulSoup(req1.text, 'html.parser')
  items = soup1.findAll('div', 'trenLatest__item clearfix') #class berita
  for it in items:
    link = it.find('a','tren__link')['href'] #class perberita (pada bagian judul)

    req2 = requests.get(link)
    soup2 = BeautifulSoup(req2.text, 'html.parser')
    judulF = soup2.find('h1', 'read__title').text    #class judul berita
    isiF = "".join(soup2.find('div', 'read__content').text.split('\n'))

    beritatren.append([judulF,isiF])

# %%
tren = pd.DataFrame(beritatren, columns=['Judul', 'Isi'])
tren['Label'] = 'tren'

gabungsemua = [combined_df, tren]
keseluruhan = pd.concat(gabungsemua, ignore_index=True)
keseluruhan
# Out:
#                                                   Judul  \
# 0     Sultan Korban Kabel Menjuntai Akan Lanjutkan K...
# 1     Aktivitas Firli Bahuri Usai Tak Aktif Jadi Ket...
# 2     Firli Bahuri Tak Hadiri Peringatan Hari Antiko...
# 3     Pemilik Bengkel di Bogor Diduga Dianiaya Tetan...
# 4     Bertambah 315 Kasus Covid-19 di Jakarta dalam ...
# ...                                                 ...
# 2645  Jawaban Anies soal Polusi Udara DKI Jakarta ya...
# 2646  Tengah Mewabah, Ini 5 Bahan Alami untuk Membas...
# 2647  Driver Gojek Bisa Nilai Penumpang, Ini Risiko ...
# 2648  Meteran Listrik Diganti AMI, Apakah Biaya List...
# 2649  4 Alasan Mengapa Tak Dianjurkan Minum Kopi Set...
#
#                                                     Isi        Label
# 0     JAKARTA, KOMPAS.com - Sultan Rif'at Alfatih, k...  megapolitan
# 1     JAKARTA, KOMPAS.com - Ketua Komisi Pemberantas...  megapolitan
# 2     JAKARTA, KOMPAS.com - Ketua Komisi Pemberantas...  megapolitan
# 3     BOGOR, KOMPAS.com - HSN (75), lansia pemilik b...  megapolitan
# 4     JAKARTA, KOMPAS.com - Dinas Kesehatan (Dinkes)...  megapolitan
# ...                                                 ...          ...
# 2645  KOMPAS.com- Debat perdana calon presiden (capr...         tren
# 2646  KOMPAS.com - Wabah kutu busuk atau kutu kasur ...         tren
# 2647  KOMPAS.com - Sebuah unggahan yang menyatakan p...         tren
# 2648  KOMPAS.co - PT PLN (Persero) memastikan akan m...         tren
# 2649  KOMPAS.com - Menyesap kopi di pagi hari sesaat...         tren
#
# [2650 rows x 3 columns]

# %% [markdown]
# ## hasil ketiga Kategori

# %%
keseluruhan.to_csv('3kategori.csv',  index=False)
